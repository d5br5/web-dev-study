# %%
import tensorflow as tf
import pandas as pd

# %%
file = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
boston = pd.read_csv(file)

# %%
boston.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
cs = boston[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'b', 'lstat']]
rs = boston[['medv']]

# %%
X = tf.keras.layers.Input(shape=[13])
H = tf.keras.layers.Dense(10, activation='swish')(X)
Y = tf.keras.layers.Dense(1)(H)
model = tf.keras.models.Model(X,Y)
model.compile(loss='mse')

# %%
model.fit(cs, rs, epochs=10000, verbose=0)

# %%
model.fit(cs, rs, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.6864
# Epoch 2/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.4468
# Epoch 3/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.7694
# Epoch 4/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.3509
# Epoch 5/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.7890
# Epoch 6/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.6469
# Epoch 7/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.6376
# Epoch 8/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.2856
# Epoch 9/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.9161
# Epoch 10/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.7496

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 13)]              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                140
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.predict(cs[0:5])
# Out:
# array([[29.2883  ],
#        [22.311731],
#        [31.20021 ],
#        [31.356157],
#        [28.324373]], dtype=float32)

# %%
rs[0:5]
# Out:
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
model.get_weights()
# Out:
# [array([[ 1.36749402e-01,  1.15738861e-01,  3.39095086e-01,
#           1.76248133e-01, -4.49263006e-01, -2.03584135e-02,
#           7.19068423e-02, -7.36324966e-01, -2.25102186e-01,
#           7.91656792e-01],
#         [ 1.46810226e-02, -3.93046588e-01, -4.99098897e-01,
#          -4.29239303e-01, -1.36305779e-01, -3.86078000e-01,
#          -1.19889602e-01, -1.30965686e+00,  7.01590061e-01,
#          -8.97331357e-01],
#         [-9.07380506e-02, -6.50226116e-01,  2.65611917e-01,
#          -1.23871028e-01,  2.68136393e-02, -2.17544824e-01,
#           2.38365710e-01, -3.52435485e-02, -4.96080756e-01,
#           1.00625253e+00],
#         [ 5.70665479e-01, -6.35058880e-01, -2.89492965e-01,
#          -7.98896849e-02,  1.60823894e+00,  4.23625052e-01,
#          -1.01845360e+00,  3.47987580e+00, -1.95938230e-01,
#           1.93820000e+00],
#         [-2.44572234e+00,  3.21265650e+00,  4.88560855e-01,
#          -4.93129939e-01, -2.58508492e+00, -1.79238141e-01,
#           2.15747738e+00, -1.25554800e-01, -2.97124058e-01,
#          -3.81797409e+00],
#         [ 3.36958170e+00,  3.25500917e+00,  1.02723375e-01,
