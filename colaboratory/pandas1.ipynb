# %%
print("hello")
# Out:
# hello

# %%
text = 'hello'
print(text)
# Out:
# hello

# %%
import pandas as pd

# %%
file_dir='https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv'
lemonade = pd.read_csv(file_dir)
file_dir='https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
boston = pd.read_csv(file_dir)
file_dir='https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv'
iris = pd.read_csv(file_dir)

# %%
print(lemonade)
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48
# 5  25   50

# %%
print(lemonade.shape)
print(boston.shape)
print(iris.shape)
# Out:
# (6, 2)
# (506, 14)
# (150, 5)

# %%
print(lemonade.columns)
print(boston.columns)
print(iris.columns)
# Out:
# Index(['온도', '판매량'], dtype='object')
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')
# Index(['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭', '품종'], dtype='object')

# %%
lemon_cause = lemonade[['온도']]
lemon_result=lemonade[['판매량']]

# %%
boston_cause = boston[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'b', 'lstat']]
boston_result = boston[['medv']]

# %%
iris_cause = iris[['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭']]
iris_result = iris[['품종']]

# %%
lemonade.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
boston.head()
# Out:
#       crim    zn  indus  chas    nox  ...  tax  ptratio       b  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]
